# %% [markdown]
# # CE-157AC
#
# ## Assignment: Problem Set #2
#
#
# _____
#
# ### Assignment Description
#
# 1) Read this recent news article:
#
# https://www.theguardian.com/education/2018/feb/01/schools-across-the-us-exposed-to-air-pollution-hildren-are-facing-risks
#
# In this problem set, we’re going to do some relatively rudimentary analyses of similar issues here in the Bay Area. In the process, you will explore the lasting effects of urban infrastructure (specifically, housing and highways) on the way exposures vary across space and communities. To do this you’ll use a variety of easily-accessible tools provided by various government agencies. One of the purposes here is to familiarize you with these sources of data so that you might take advantage of them in your future work.
#
# ----
#
# _If you're so inclinded, check out the study they are referencing:_
#
# https://www.sciencedirect.com/science/article/pii/S0013935117317188

# %% [markdown]
# ____
# ### 1) Exploring the East Bay's census map
#
# Go to the US Census Explorer: http://census.socialexplorer.com/pop-flash/
#
# **Zoom _in on_ the east bay area**
#
# - Bound your search between _Martinez, Richmond, Hayward, and Pleasanton_. You’ll want to zoom in further within this boundary, but keep your zoomed-in map within this area.
#
#
#
# - Make sure you are viewing by _**Census Tract**_
#
# _____
#
# **Under "Select a Measure" - explore!**
# - Select one measure that you find interesting, take a screen shot of that map (https://www.take-a-screenshot.org/ for a how to), and copy the map into your assignment.
#
#         Note: do not choose "Median Household Income" for this part

# %% [markdown]
# **Here's an example of my map**
#
#
# ![](images/Masters_degree.png)

# %% [markdown]
# **After taking a screenshot of the map**, please add the image to the "image" folder and then proceed to the following below:

# %% [markdown]
# My map file was called **Masters_degree.png**
#
# I added the screenshot here by typing the following into a Markdown Cell
# like so:
#
#         ![](images/Masters_degree.png)
#
#
#
# Please copy the exact code above and change the name of your map accordingly with the extension of **.png** at the end.

# %% [markdown]
# ![](images/...)

# %% [markdown]
# _____
# ### Responses
# **Write 2-3 Sentences below**
# - What is interesting to you about this map and why?
# - How do you interpret it?

# %% [raw]
# Please erase everything and write your sentences here.

# %% [markdown]
# -----
#
# Then under ** "Select a Measure" ** please select ** "Median Househould Income" ** for the next question
#
#
# ____

# %% [markdown]
# ### 2) Exploring age of housing as a potential source of lead exposure
#
# Find three East Bay elementary schools that fit the following criteria:
#    - At least 250 students
#    - Each is located in a census tract with ** > $15,000 ** difference in median income from the other schools you choose
#
#
# This will take some creative searching – perhaps use **google maps** to find elementary schools in a specific area, then check the **“Median Household Income”** image from the previous problem to ensure that the schools are located within census tracts with large income differences. Alternatively – use the tool that you used for the first problem set and you can map school locations there as well.
#
# **Note the addresses and census tract numbers for each school.**

# %% [markdown]
# ---
#
# **For Example, these are my three schools:**
#
# **Cleveland Elementary School**
# - 745 Cleveland St, Oakland, CA 94606
# - Census Track Number 4066.02
# - $50,341 Median Household Income
#
# **Maya Lin School**
# - 825 Taylor Ave, Alameda, CA 94501
# - Census Track Number 4278
# - $81,375 Median Household Income
#
# **Lincoln Elementary School**
# - 29 S 6th St, Richmond, CA 94801
# - Census Track Number 3770
# - $31,350 Median Household Income
#
#
#
# I just used **Google maps** to find elementary schools in the Bay Area and then I went back to the previous school to see their Median Household Income depending on the region of the map

# %% [markdown]
# -------
# ### Create one map showing the location of each school you have chosen.
#
#
# There are a number of ways to do this, one straightforward method is to use https://www.google.com/maps/d/u/0/.
#
# **Simply put:**
# 1. Select **Create a new map** from the menu on the top left corner (three bars).
# 2. **Enter the school’s address** in the search bar.
# 3. **Move the mouse over the green pin** that is dropped onto the map, and in the box that appears **select “Add to Map”.**
# 4. Do this for each school.
#     - You can add a description for each point on the map (i.e. the school name) and display these.
# 5. Finally, take a **screenshot of your map.**

# %% [markdown]
# -----
#
# ### Here's an example of my map with three elementary schools from above
#
# ![](images/Elem_Schools.png)

# %% [markdown]
# ---------
#
# ### Go to the US Census Bureau FactFinder:** http://factfinder2.census.gov/
#
# - Select ** Advance Search** and **Show me all**
# - On the left side, click **Geographies** and then click **Address**
# - Enter the address of one of your schools and click **Go**
# - Click on the appropriate census tract
#     - It Should have the link with the **Geography Type** listed as **Census Tract**. After you click the link, this census tract should show up on the left side under **Your Selections**
#
#
# - Now repeat this for the other two schools you have chosen
#     - You should now have **three** census tracts chosen under **Your Selections**
#
# -----
#
# **It should look like this**
#
# ![](images/Your_Selections.png)

# %% [markdown]
# ------
#
# Click on **Topics** and then close the pop-up window that appears
#
# **We are going to look at multiple tables:**
#
#         DP02: SELECTED SOCIAL CHARACTERISTICS…
#         DP03: SELECTED ECONOMIC CHARACTERISTICS
#         DP04: SELECTED HOUSING CHARACTERISTICS
#         DP05: ACS DEMOGRAPHIC AND HOUSING ESTIMATES
#         S1701: POVERTY STATUS IN THE PAST 12 MONTHS

# %% [markdown]
# ---
# **Some notes:**
# 1. Search for the appropriate data set in the **“topic or table name”** box
# 2. **Capitalization counts**
# 3. When you get the list of tables, **select the appropriate one (use the 2016 ACS 5-year estimates)**
# 4. After selecting the check-box next to the table you are interested in, **you need to clear the search before you do the next one – in the “Your Selections”** box on the upper left just clear out that search, then perform the next one. Every time you select one of the check-boxes the site remembers your selections.
# 5. After selecting all of the tables, **you can click “View” to view each table and then download the data as an Excel file.** Note that you must download each table separately (and if you download them immediately from the search page you’ll get them as csv files). Note to do that from the “View” section you can modify the table and only select the data you are interested in prior to downloading.

# %%
from datascience import *

dp02 = Table.read_table("tables/ACS_16_5YR_DP02_with_ann.csv")
dp02
# Out:
# GEO.id               | GEO.id2     | GEO.display-label                                  | HC01_VC03                                       | HC02_VC03                                              | HC03_VC03                                      | HC04_VC03                                                    | HC01_VC04                                                    | HC02_VC04                                                    | HC03_VC04                                                    | HC04_VC04                                                    | HC01_VC05                                                    | HC02_VC05                                                    | HC03_VC05                                                    | HC04_VC05                                                    | HC01_VC06                                                    | HC02_VC06                                                    | HC03_VC06                                                  
# ...

# %%
dp03 = Table.read_table("tables/ACS_16_5YR_DP03_with_ann.csv")
dp03
# Out:
# GEO.id               | GEO.id2     | GEO.display-label                                  | HC01_VC03                                                  | HC02_VC03                                                    | HC03_VC03                                                 | HC04_VC03                                                    | HC01_VC04                                                    | HC02_VC04                                                    | HC03_VC04                                                    | HC04_VC04                                                    | HC01_VC05                                                    | HC02_VC05                                                    | HC03_VC05                                                    | HC04_VC05                                                    | HC01_VC06                                                    | HC02_VC06                                                    | HC03_VC06                      
# ...

# %%
dp04 = Table.read_table("tables/ACS_16_5YR_DP04_with_ann.csv")
dp04
# Out:
# GEO.id               | GEO.id2     | GEO.display-label                                  | HC01_VC03                                         | HC02_VC03                                                | HC03_VC03                                        | HC04_VC03                                                    | HC01_VC04                                                    | HC02_VC04                                                    | HC03_VC04                                                    | HC04_VC04                                                    | HC01_VC05                                                    | HC02_VC05                                                    | HC03_VC05                                                    | HC04_VC05                                                    | HC01_VC08                                            | HC02_VC08                                                   | HC03_VC08                                           | HC04_VC0
# ...

# %%
dp05 = Table.read_table("tables/ACS_16_5YR_DP05_with_ann.csv")#
dp05
# Out:
# GEO.id               | GEO.id2     | GEO.display-label                                  | HC01_VC03                                | HC02_VC03                                       | HC03_VC03                               | HC04_VC03                                               | HC01_VC04                                       | HC02_VC04                                              | HC03_VC04                                      | HC04_VC04                                                    | HC01_VC05                                         | HC02_VC05                                                | HC03_VC05                                        | HC04_VC05                                                    | HC01_VC08                             | HC02_VC08                                    | HC03_VC08                            | HC04_VC08                                            | HC01_VC09                            | HC02_VC09                                   | HC03_
# ...

# %%
s1701 = Table.read_table("tables/ACS_16_5YR_S1701_with_ann.csv")
s1701
# Out:
# GEO.id               | GEO.id2     | GEO.display-label                                  | HC01_EST_VC01                                                | HC01_MOE_VC01                                                | HC02_EST_VC01                                                | HC02_MOE_VC01                                                | HC03_EST_VC01                                                | HC03_MOE_VC01                                                | HC01_EST_VC03                         | HC01_MOE_VC03                                | HC02_EST_VC03                                       | HC02_MOE_VC03                                              | HC03_EST_VC03                                               | HC03_MOE_VC03                                                | HC01_EST_VC04                                         | HC01_MOE_VC04                                                | HC02_EST_VC04                                                | HC02_MOE_VC04        
# ...

# %% [markdown]
# -----
# ## Coding
#
# ### Create a well-organized table with the following information for each of your school census tracts:**
#
#  _This will require exploring within the above tables. For example, to see the % of structures built before or after a certain year, you will need to click on " DP04: SELECTED HOUSING CHARACTERISTICS"._
#
# _Do not overload us with data! Presentation and legibility are very important here._
#
#
# ----
#
# School Address
#
# Census Tract Number
#
# Total Population
#
# % Population
#    - Under 5 years
#    - 5 to 19 years (you will have to add numbers to get this)
#
# % Population enrolled in elementary school
#
# % Population “Language other than English” spoken at home
#
# % Population with “No health insurance coverage”
#
# % Non-White (Calculate: Total Population - Not Hispanic/Latino White alone)
#
# % of population in each of the top 3 represented racial categories
# - Focus on the broad categories, not the most-specific breakdowns
#
# - i.e. White, Black or African American, American Indian and Alaskan Native, Asian, etc.
#
# - List these individually – three values – not a sum of these values
# % Hispanic or Latino
#
# % Year Structure Built (you’ll have to add percentages here)
# - 1980 or later
# - Before 1980
#
# % Total population below poverty level
#
# % Population under 18 years below poverty level
#
# ----

# %% [markdown]
# ### Response
#
# Lead was banned from household paints in the United States in 1978, and houses constructed before this year are likely to contain lead paint. Is there a difference in the age of housing surrounding your three schools? How does this difference related to the other demographic characteristics of the census tracts where the schools are located (race/poverty/English as a Second Language (ESL))

# %% [markdown]
# Please erase everything and write your sentences here.

# %% [markdown]
# ### Write two to three sentences explaining:
# - Any relationships that you see across your three school census areas

# %% [markdown]
# Please erase everything and write your sentences here.

# %% [markdown]
# ---
#
# ## 3) Estimating children's toxics exposure from traffic
#
#
# Starting in 1970, the USEPA moved to phase-out lead in gasoline. Ethyl Corporation (now known as NewMarket Corporation), the company that produced the lead-containing additive TEL that was regularly added to gasoline to prevent engine-knock and boost octane, attempted to block this process through a lawsuit. The basis for this lawsuit: there was no scientific evidence that lead was any more harmful than the gasoline itself. This reasoning should remind you of other issues we have spoken about in class – such arguments assuring the safety of TEL have their roots in the 1920’s, and in fact in 1926 the US Surgeon General assured the public that TEL was hazardous to human health. The EPA eventually won the suit and the phase-out began 1976. In 1996 lead was completely banned from motor vehicle gasoline in the United States.
#
# While lead is no longer in our gasoline, soil near roadways still tends to exhibit higher lead concentrations, particularly in urban and higher-traffic areas, and soil is a main route of transmission for small children (who are most susceptible to its neurotoxic effects). In addition to lead, traffic exhaust contains other neuro-developmental toxins, which may lead to worse outcomes when combined with lead exposure, although the science here is still in its infancy.
#
# -----
#
# 1. Go to the Cal EnviroScreen 3.0 website:
# https://oehha.ca.gov/calenviroscreen/report/calenviroscreen-30
# 2. Scroll down to the CalEnviroScreen 3.0 Map and open the map (where it says “Map of CalEnviroScreen 3.0 Results”).
#     - Note that some browsers may not work, and adblockers may disrupt the function of this tool.
# 3. Enter the address of the school and click on the census tract.

# %% [markdown]
# ----
# ###  Responses & Coding
#
#
# 1. What is the traffic volumes (the data is given in vehicle-km/hr) for each of your schools’ census tracts?
#
# 2. What other forms of pollution stand out, and how do they compare across your census tracts? Create a small table of appropriate data.

# %% [markdown]
# Please erase everything and write your sentences here.

# %% [markdown]
# ----
#
# ### In two to three sentences
# - Considering housing age and traffic exposure, are schools in neighborhoods with older houses also surrounded by greater traffic density?
# - Do the patterns of cumulative potential sources of lead exposure differ along socioeconomic lines, and if so how?

# %% [markdown]
# Please erase everything and write your sentences here.

# %% [markdown]
# ### In two to three sentences, explain why this might happen:
#
# - Some students might find that there is a positive correlation between old housing, traffic, and wealth – why might this be the case?
#     - Be sure to consider the changing geographies of poverty as well as where kids might be going to school.

# %% [markdown]
# Please erase everything and write your sentences here.
